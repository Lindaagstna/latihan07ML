# %% [markdown]
# <a href="https://colab.research.google.com/github/Lindaagstna/latihan07ML/blob/main/latihan07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/SEMESTER3/praktikum_ml/praktikum07/data/dataset_satelit.csv")
df.head()
# Out:
#    No   Longitude  Lattitude     N     P      K    Ca    Mg      Fe      Mn  \
# 0   1  103.036658  -0.604417  2.64  0.15  0.415  0.51  0.31  119.96  463.23
# 1   2  103.037201  -0.604689  2.75  0.17  0.568  0.76  0.58  102.63  493.81
# 2   3  103.036359  -0.603012  1.77  0.12  0.339  0.49   0.6  107.37  460.93
# 3   4  103.036950  -0.603219  2.30  0.15  0.460  0.74  0.67   96.02  338.17
# 4   5  103.036802  -0.601969  2.05  0.14  0.308  0.64  0.72   87.01  384.33
#
#    ...      b1  Sigma_VV  Sigma_VH      plia       lia      iafe  gamma0_vv  \
# 0  ...  0.0433   0.18183   0.04461  35.74446  35.79744  35.41161    0.22331
# 1  ...  0.0465   0.22079   0.04640  35.12096  35.14591  35.41510    0.27116
# 2  ...  0.0417   0.18926   0.03992  35.07724  35.07730  35.41135    0.23242
# 3  ...  0.0367   0.14769   0.03622  36.08078  36.08469  35.41583    0.18138
# 4  ...  0.0361   0.18205   0.03797  32.68855  32.69293  35.41592    0.22359
#
#    gamma0_vh  beta0_vv  beta0_vh
# ...

# %%
df.describe()
# Out:
#                No   Longitude   Lattitude           N           P           K  \
# count  594.000000  594.000000  594.000000  594.000000  594.000000  593.000000
# mean   297.500000  106.878644   -1.024933    2.259091    0.141380    0.582175
# std    171.617307    4.949840    0.965349    0.395499    0.019782    0.222567
# min      1.000000  102.760857   -2.333750    1.140000    0.090000    0.122000
# 25%    149.250000  102.927811   -2.233338    1.982500    0.130000    0.429000
# 50%    297.500000  103.581969   -0.602276    2.280000    0.140000    0.549000
# 75%    445.750000  113.403797   -0.257349    2.570000    0.150000    0.710000
# max    594.000000  113.434700    0.069251    3.230000    0.220000    1.489000
#
#                Ca          Fe           Mn          Cu  ...          b1  \
# count  594.000000  594.000000   594.000000  594.000000  ...  594.000000
# mean     0.595094   74.613771   308.034697    2.391195  ...    0.177291
# ...

# %%
#mengubah fitur mg menjadi float
df['Mg'] = pd.to_numeric(df['Mg'], errors='coerce')

#menghapus baris yang memiliki missing value
df = df.dropna()

# %%
x = df[["b2", "b3", "b4", "b8", "b11",
        "Sigma_VV", "Sigma_VH"]]
y = df["N"]

# %%
x_train, x_test, y_train, y_test = train_test_split (
    x, y, test_size=0.2, random_state=42
)

print("Jumlah data train:", len(x_train))
print("Jumlah data test:", len(x_test))

model = LinearRegression()

#training data
model.fit(x_train, y_train)
# Out:
# Jumlah data train: 473
# Jumlah data test: 119
# LinearRegression()

# %%
#testing
y_pred = model.predict(x_test)

#evaluasi
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print("R2 Score:", r2)
print("RMSE:", mse)
# Out:
# R2 Score: 0.20193023352881245
# RMSE: 0.12249565575528841

# %%
x_train_const = sm.add_constant(x_train)
x_test_const = sm.add_constant(x_test)
model = sm.OLS(y_train, x_train_const).fit()
print("\n--- Ringkasan Model OLS ---")
print(model.summary())
# Out:
# --- Ringkasan Model OLS ---
#                             OLS Regression Results
# ...
# Dep. Variable:                      N   R-squared:                       0.329
# Model:                            OLS   Adj. R-squared:                  0.319
# Method:                 Least Squares   F-statistic:                     32.52
# Date:                Sat, 08 Nov 2025   Prob (F-statistic):           9.34e-37
# Time:                        06:29:58   Log-Likelihood:                -139.19
# No. Observations:                 473   AIC:                             294.4
# Df Residuals:                     465   BIC:                             327.7
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.5073      0.108     23.173      0.000       2.295       2.720
# ...

# %%
x_test_const = sm.add_constant(x_test)
y_pred_test = model.predict(x_test_const)

hasil = pd.DataFrame({
    "N_aktual": y_test.to_numpy(),
    "N_prediksi": y_pred_test
})

for col in x_test.columns:
    hasil[col] = x_test[col].to_numpy()


hasil["Selisih error"] = hasil["N_prediksi"] - hasil["N_aktual"]

denom = 1e-6
hasil["Akurasi (%)"] = (1 - (hasil["Selisih error"].abs() / (hasil["N_aktual"] + denom))).clip(lower=0, upper=1) * 100

hasil
# Out:
#      N_aktual  N_prediksi      b2      b3       b4        b8      b11  \
# 501      2.41    2.459449  0.2472  0.1345  0.04972  40.09767  0.02576
# 589      2.49    3.821183  0.0528  0.0186  0.06668  40.17345  0.03464
# 197      2.18    2.177418  0.3836  0.3450  0.29280   0.42440  0.18410
# 166      2.17    2.211086  0.2780  0.2596  0.22700   0.37940  0.18150
# 545      2.67    2.680426  0.1558  0.0603  0.06339  40.19756  0.03296
# ..        ...         ...     ...     ...      ...       ...      ...
# 433      1.28    2.071146  0.2470  0.2352  0.21220   0.36040  0.29320
# 236      2.15    2.195181  0.1494  0.1510  0.13000   0.35500  0.17290
# 303      1.92    2.085689  0.0634  0.0886  0.05440   0.39480  0.18590
# 214      2.45    2.272438  0.2028  0.2034  0.18720   0.35140  0.17220
# 240      2.43    2.201754  0.1460  0.1520  0.12960   0.35380  0.17370
#
#      Sigma_VV  Sigma_VH  Selisih error  Akurasi (%)
# 501   0.28460   0.29500       0.049449    97.948180
# ...

# %%
hasil['Akurasi (%)'].mean()
# Out:
# np.float64(87.15910120840465)

# %%
hasil['Selisih error'].abs().mean()
# Out:
# np.float64(0.26411309416381784)
